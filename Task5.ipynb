# %% [markdown]
# # The Sparks Foundation
# # Data Science and Business Analytics
# # Name-Srideep Bhattacharya

# %% [markdown]
# # As a sports analyst,find out most successful teams,players and factors contributing to win or loss of a team.Suggest teams or players companies should endorse for its products.

# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
#reading the dataset
df=pd.read_csv("matches.csv");
df1=pd.read_csv("deliveries.csv");
df1.shape #dimension check of our dataset.
# Out:
# (179078, 21)

# %%
df.shape #dimension check of our dataset.
# Out:
# (756, 18)

# %% [markdown]
# # Data preprocessing

# %%
df1.head(10) #first 10 rows of dataset
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 5         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 6         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 7         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 8         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 9         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
#
#    ball    batsman non_striker       bowler  is_super_over  ...  bye_runs  \
# ...

# %%
df.head(10) #first 10 rows of data.
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5   6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 6   7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
# 7   8    2017     Indore  2017-04-10  Royal Challengers Bangalore
# 8   9    2017       Pune  2017-04-11             Delhi Daredevils
# 9  10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# ...

# %%
df.isnull().sum() #checking for null values
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
df1.isnull().sum() #checking for null values
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# is_super_over            0
# wide_runs                0
# bye_runs                 0
# legbye_runs              0
# noball_runs              0
# penalty_runs             0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# player_dismissed    170244
# dismissal_kind      170244
# fielder             172630
# dtype: int64

# %%
df.describe() #calculating certain parameters
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    756.000000   756.000000  756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    0.025132    13.283069        3.350529
# std     3464.478148     3.366895    0.156630    23.471144        3.387963
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.750000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.500000  2013.000000    0.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    0.000000    19.000000        6.000000
# max    11415.000000  2019.000000    1.000000   146.000000       10.000000

# %%
df1.describe() #calculating certain parameters
# Out:
#             match_id         inning           over           ball  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean     1802.252957       1.482952      10.162488       3.615587
# std      3472.322805       0.502074       5.677684       1.806966
# min         1.000000       1.000000       1.000000       1.000000
# 25%       190.000000       1.000000       5.000000       2.000000
# 50%       379.000000       1.000000      10.000000       4.000000
# 75%       567.000000       2.000000      15.000000       5.000000
# max     11415.000000       5.000000      20.000000       9.000000
#
#        is_super_over      wide_runs       bye_runs    legbye_runs  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean        0.000452       0.036721       0.004936       0.021136
# std         0.021263       0.251161       0.116480       0.194908
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %% [markdown]
# # Some columns have almost the entire data missing,so we do dimensionality reduction for better analysis.

# %%
df1.drop('player_dismissed',axis=1,inplace=True) #dropping irrelevant columns which won't help

# %%
df1.drop('dismissal_kind',axis=1,inplace=True)

# %%
df1.drop('fielder',axis=1,inplace=True)

# %%
df1.shape #new dimensions
# Out:
# (179078, 18)

# %%
df.drop('umpire3',axis=1,inplace=True)

# %%
df.dtypes #datatype of attributes of dataset.
# Out:
# id                  int64
# season              int64
# city               object
# date               object
# team1              object
# team2              object
# toss_winner        object
# toss_decision      object
# result             object
# dl_applied          int64
# winner             object
# win_by_runs         int64
# win_by_wickets      int64
# player_of_match    object
# venue              object
# umpire1            object
# umpire2            object
# dtype: object

# %%
df1.dtypes
# Out:
# match_id          int64
# inning            int64
# batting_team     object
# bowling_team     object
# over              int64
# ball              int64
# batsman          object
# non_striker      object
# bowler           object
# is_super_over     int64
# wide_runs         int64
# bye_runs          int64
# legbye_runs       int64
# noball_runs       int64
# penalty_runs      int64
# batsman_runs      int64
# extra_runs        int64
# total_runs        int64
# dtype: object

# %%
df.corr()  #coorelation between different attributes
# Out:
#                       id    season  dl_applied  win_by_runs  win_by_wickets
# id              1.000000  0.668304   -0.011658    -0.039403       -0.012239
# season          0.668304  1.000000   -0.001116    -0.037529       -0.009379
# dl_applied     -0.011658 -0.001116    1.000000    -0.016349       -0.011631
# win_by_runs    -0.039403 -0.037529   -0.016349     1.000000       -0.560420
# win_by_wickets -0.012239 -0.009379   -0.011631    -0.560420        1.000000

# %%
df1.corr()
# Out:
#                match_id    inning      over      ball  is_super_over  \
# match_id       1.000000  0.003958  0.008268 -0.001349      -0.009150
# inning         0.003958  1.000000 -0.050076 -0.003943       0.084154
# over           0.008268 -0.050076  1.000000 -0.007424      -0.034329
# ball          -0.001349 -0.003943 -0.007424  1.000000      -0.001143
# is_super_over -0.009150  0.084154 -0.034329 -0.001143       1.000000
# wide_runs     -0.007549  0.001201 -0.010003 -0.004665      -0.001019
# bye_runs       0.000905 -0.000757  0.012111  0.006602       0.001353
# legbye_runs   -0.012429 -0.001996 -0.004764 -0.002727       0.001735
# noball_runs   -0.004623 -0.000904  0.016984  0.000567       0.013640
# penalty_runs  -0.001475  0.003442 -0.000979  0.000711      -0.000071
# batsman_runs   0.033510 -0.005362  0.086701  0.007950       0.010125
# extra_runs    -0.013323 -0.000531 -0.002479 -0.002576       0.003504
# total_runs     0.030727 -0.005485  0.086326  0.007414       0.010891
#
# ...

# %% [markdown]
# # Analysis of data to draw insights

# %%
df["winner"].value_counts().plot.bar() #We find Mumbai Indians have won most matches.
# Out:
# <AxesSubplot:>

# %%
df["toss_winner"].value_counts().plot.bar() #Also,the team has won the toss maximum number of times
# Out:
# <AxesSubplot:>

# %%
df["toss_decision"].value_counts().plot.bar() #Opting to field has been the preferred choice for toss winners.
# Out:
# <AxesSubplot:>

# %%
df.groupby("toss_decision")["winner"].value_counts().plot.bar()
#Teams seem to have more matches cumulatively on chasing.
# Out:
# <AxesSubplot:xlabel='toss_decision,winner'>

# %%
df["player_of_match"].value_counts() #Chris Gayle is the most successful player.
# Out:
# CH Gayle           21
# AB de Villiers     20
# MS Dhoni           17
# RG Sharma          17
# DA Warner          17
#                    ..
# S Badrinath         1
# DJG Sammy           1
# AA Jhunjhunwala     1
# AD Mathews          1
# AC Voges            1
# Name: player_of_match, Length: 226, dtype: int64

# %%
df.groupby(df["dl_applied"]==1)["winner"].value_counts() 
#Kolkata Knight Riders have won maximum matches through DL method.
# Out:
# dl_applied  winner
# False       Mumbai Indians                 109
#             Chennai Super Kings             98
#             Kolkata Knight Riders           88
#             Royal Challengers Bangalore     81
#             Kings XI Punjab                 80
#             Rajasthan Royals                74
#             Delhi Daredevils                65
#             Sunrisers Hyderabad             56
#             Deccan Chargers                 29
#             Gujarat Lions                   13
#             Pune Warriors                   12
#             Delhi Capitals                  10
#             Rising Pune Supergiant          10
#             Kochi Tuskers Kerala             5
#             Rising Pune Supergiants          3
# True        Kolkata Knight Riders            4
#             Royal Challengers Bangalore      3
#             Chennai Super Kings              2
#             Delhi Daredevils                 2
# ...

# %%
df["season"].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0      2017
# 1      2017
# 2      2017
# 3      2017
# 4      2017
#        ...
# 751    2019
# 752    2019
# 753    2019
# 754    2019
# 755    2019
# Name: season, Length: 756, dtype: int64>

# %%
df.groupby(df["dl_applied"]==1)["winner"].value_counts().plot.bar()
# Out:
# <AxesSubplot:xlabel='dl_applied,winner'>

# %%
df1.tail() #last 5 observations of dataset.
# Out:
#         match_id  inning         batting_team    bowling_team  over  ball  \
# 179073     11415       2  Chennai Super Kings  Mumbai Indians    20     2
# 179074     11415       2  Chennai Super Kings  Mumbai Indians    20     3
# 179075     11415       2  Chennai Super Kings  Mumbai Indians    20     4
# 179076     11415       2  Chennai Super Kings  Mumbai Indians    20     5
# 179077     11415       2  Chennai Super Kings  Mumbai Indians    20     6
#
#           batsman non_striker      bowler  is_super_over  wide_runs  bye_runs  \
# 179073  RA Jadeja   SR Watson  SL Malinga              0          0         0
# 179074  SR Watson   RA Jadeja  SL Malinga              0          0         0
# 179075  SR Watson   RA Jadeja  SL Malinga              0          0         0
# 179076  SN Thakur   RA Jadeja  SL Malinga              0          0         0
# 179077  SN Thakur   RA Jadeja  SL Malinga              0          0         0
#
# ...

# %%
df1["match_id"].unique
# Out:
# <bound method Series.unique of 0             1
# 1             1
# 2             1
# 3             1
# 4             1
#           ...
# 179073    11415
# 179074    11415
# 179075    11415
# 179076    11415
# 179077    11415
# Name: match_id, Length: 179078, dtype: int64>

# %%
df.groupby("season")["winner"].value_counts()
# Out:
# season  winner
# 2008    Rajasthan Royals               13
#         Kings XI Punjab                10
#         Chennai Super Kings             9
#         Delhi Daredevils                7
#         Mumbai Indians                  7
#                                        ..
# 2019    Kings XI Punjab                 6
#         Kolkata Knight Riders           6
#         Sunrisers Hyderabad             6
#         Rajasthan Royals                5
#         Royal Challengers Bangalore     5
# Name: winner, Length: 100, dtype: int64

# %%
venue_ser =df['venue'].value_counts() #Eden Gardens have hosted maximum matches.
venue_ser
# Out:
# Eden Gardens                                            77
# M Chinnaswamy Stadium                                   73
# Wankhede Stadium                                        73
# Feroz Shah Kotla                                        67
# Rajiv Gandhi International Stadium, Uppal               56
# MA Chidambaram Stadium, Chepauk                         49
# Sawai Mansingh Stadium                                  47
# Punjab Cricket Association Stadium, Mohali              35
# Maharashtra Cricket Association Stadium                 21
# Dr DY Patil Sports Academy                              17
# Subrata Roy Sahara Stadium                              17
# Kingsmead                                               15
# Punjab Cricket Association IS Bindra Stadium, Mohali    14
# Sardar Patel Stadium, Motera                            12
# SuperSport Park                                         12
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium     11
# ...

# %%
venue_df = pd.DataFrame(columns=['venue', 'matches'])
for items in venue_ser.iteritems():
    temp_df = pd.DataFrame({
        'venue':[items[0]],              #Creating a new dataset containing venue and matches.
        'matches':[items[1]]
    })
    venue_df = venue_df.append(temp_df, ignore_index=True)

# %%
plt.figure(figsize=(14,7),dpi=200)    #Plotting the results.
plt.title("IPL Venues")
sns.barplot(x='matches', y='venue', data=venue_df);

# %%
team=df["winner"].value_counts() 
team
# Out:
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Delhi Capitals                  10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: winner, dtype: int64

# %%
team_df=pd.DataFrame(columns=['team','wins'])  #Creating a new dataset.

# %%
for item in team.iteritems():
    temp=pd.DataFrame({'team':[item[0]],'wins':[item[1]]})
    team_df=team_df.append(temp,ignore_index=True)

# %%
sns.barplot(x='wins',y='team',data=team_df,palette='Paired')   #Plotting the results.
# Out:
# <AxesSubplot:xlabel='wins', ylabel='team'>

# %% [markdown]
# # After analysis,we find out that Mumbai Indians is the most successful team in IPL as it has won the highest number of matches. Chennai Super Kings and Kolkata Knight Riders are in the queue too of winning many matches. Amongst players, Chris Gayle has been the player of match most times.AB de Villers and MS Dhoni are in second and third position.These are some players and teams companies should endorse for its products.
# # Teams opting to field are winning more in comparison to opting to bat.Eden Gardens hosted maximum number of matches in IPL.
